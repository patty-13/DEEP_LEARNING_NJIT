# %% [markdown]
# <a href="https://colab.research.google.com/github/patty-13/DEEP_LEARNING_NJIT/blob/main/HW9_DEEPLEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Homework 9 - Adversarial Attack**

# %% [markdown]
# ## Enviroment & Download
#
# We make use of [pytorchcv](https://pypi.org/project/pytorchcv/) to obtain CIFAR-10 pretrained model, so we need to set up the enviroment first. We also need to download the data (200 images) which we want to attack.

# %%
# set up environment
# !pip install pytorchcv

# download
#!gdown --id 'YOUR OWN DATA LINK' -O data.zip
from google.colab import drive
drive.mount('/content/gdrive')
# unzip
# Out:
# Collecting pytorchcv
#   Downloading pytorchcv-0.0.67-py2.py3-none-any.whl (532 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.4/532.4 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorchcv) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pytorchcv) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pytorchcv) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pytorchcv) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pytorchcv) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pytorchcv) (2023.7.22)
# Installing collected packages: pytorchcv
# Successfully installed pytorchcv-0.0.67
# Mounted at /content/gdrive

# %%
# !unzip '/content/gdrive/MyDrive/adversial_attack.zip'
# !rm '/content/gdrive/MyDrive/adversial_attack.zip'
# Out:
# Archive:  /content/gdrive/MyDrive/adversial_attack.zip
#    creating: data/
#   inflating: __MACOSX/._data
#    creating: data/cat/
#   inflating: __MACOSX/data/._cat
#   inflating: data/.DS_Store
#   inflating: __MACOSX/data/._.DS_Store
#    creating: data/dog/
#   inflating: __MACOSX/data/._dog
#    creating: data/truck/
#   inflating: __MACOSX/data/._truck
#    creating: data/bird/
#   inflating: __MACOSX/data/._bird
#    creating: data/airplane/
#   inflating: __MACOSX/data/._airplane
#    creating: data/ship/
#   inflating: __MACOSX/data/._ship
#    creating: data/frog/
#   inflating: __MACOSX/data/._frog
#    creating: data/horse/
#   inflating: __MACOSX/data/._horse
#    creating: data/deer/
#   inflating: __MACOSX/data/._deer
#    creating: data/automobile/
#   inflating: __MACOSX/data/._automobile
#   inflating: data/cat/cat17.png
#   inflating: __MACOSX/data/cat/._cat17.png
#   inflating: data/cat/cat1.png
#   inflating: __MACOSX/data/cat/._cat1.png
#   inflating: data/cat/cat16.png
#   inflating: __MACOSX/data/cat/._cat16.png
#   inflating: data/cat/cat14.png
#   inflating: __MACOSX/data/cat/._cat14.png
#   inflating: data/cat/cat2.png
#   inflating: __MACOSX/data/cat/._cat2.png
#   inflating: data/cat/cat3.png
#   inflating: __MACOSX/data/cat/._cat3.png
#   inflating: data/cat/cat15.png
#   inflating: __MACOSX/data/cat/._cat15.png
#   inflating: data/cat/cat11.png
#   inflating: __MACOSX/data/cat/._cat11.png
#   inflating: data/cat/cat7.png
#   inflating: __MACOSX/data/cat/._cat7.png
#   inflating: data/cat/cat6.png
#   inflating: __MACOSX/data/cat/._cat6.png
#   inflating: data/cat/cat10.png
#   inflating: __MACOSX/data/cat/._cat10.png
#   inflating: data/cat/cat12.png
#   inflating: __MACOSX/data/cat/._cat12.png
#   inflating: data/cat/cat4.png
#   inflating: __MACOSX/data/cat/._cat4.png
#   inflating: data/cat/cat5.png
#   inflating: __MACOSX/data/cat/._cat5.png
#   inflating: data/cat/cat13.png
#   inflating: __MACOSX/data/cat/._cat13.png
#   inflating: data/cat/cat8.png
#   inflating: __MACOSX/data/cat/._cat8.png
#   inflating: data/cat/cat9.png
# * $\epsilon$ is fixed to be 8. But on **Data section**, we will first apply transforms on raw pixel value (0-255 scale) **by ToTensor (to 0-1 scale)** and then **Normalize (subtract mean divide std)**. $\epsilon$ should be set to $\frac{8}{255 * std}$ during attack.
#
# * Explaination (optional)
#     * Denote the first pixel of original image as $p$, and the first pixel of adversarial image as $a$.
#     * The $\epsilon$ constraints tell us $\left| p-a \right| <= 8$.
#     * ToTensor() can be seen as a function where $T(x) = x/255$.
#     * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#     * After applying ToTensor() and Normalize() on $p$ and $a$, the constraint becomes $\left| N(T(p))-N(T(a)) \right| = \left| \frac{\frac{p}{255}-mean}{std}-\frac{\frac{a}{255}-mean}{std} \right| = \frac{1}{255 * std} \left| p-a \right| <= \frac{8}{255 * std}.$
#     * So, we should set $\epsilon$ to be $\frac{8}{255 * std}$ after ToTensor() and Normalize().

# %%
import torch
import torch.nn as nn

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

batch_size = 8

# the mean and std are the calculated statistics from cifar_10 dataset
cifar_10_mean = (0.491, 0.482, 0.447) # mean for the three channels of cifar_10 images
cifar_10_std = (0.202, 0.199, 0.201) # std for the three channels of cifar_10 images

# convert mean and std to 3-dimensional tensors for future operations
mean = torch.tensor(cifar_10_mean).to(device).view(3, 1, 1)
std = torch.tensor(cifar_10_std).to(device).view(3, 1, 1)

epsilon = 8/255/std
# TODO: iterative fgsm attack
# alpha (step size) can be decided by yourself
alpha = 0.8/255/std

root = './data' # directory for storing benign images
# benign images: images which do not contain adversarial perturbations
# adversarial images: images which include adversarial perturbations

# %% [markdown]
# ## Data
#
# Construct dataset and dataloader from root directory. Note that we store the filename of each image for future usage.

# %%
import os
import glob
import shutil
import numpy as np
from PIL import Image
from torchvision.transforms import transforms
from torch.utils.data import Dataset, DataLoader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar_10_mean, cifar_10_std)
])

class AdvDataset(Dataset):
    def __init__(self, data_dir, transform):
        self.images = []
        self.labels = []
        self.names = []
        '''
        data_dir
        ├── class_dir
        │   ├── class1.png
        │   ├── ...
        │   ├── class20.png
        '''
        for i, class_dir in enumerate(sorted(glob.glob(f'{data_dir}/*'))):
            images = sorted(glob.glob(f'{class_dir}/*'))
            self.images += images
            self.labels += ([i] * len(images))
            self.names += [os.path.relpath(imgs, data_dir) for imgs in images]
        self.transform = transform
    def __getitem__(self, idx):
        image = self.transform(Image.open(self.images[idx]))
        label = self.labels[idx]
        return image, label
    def __getname__(self):
        return self.names
    def __len__(self):
        return len(self.images)

adv_set = AdvDataset(root, transform=transform)
adv_names = adv_set.__getname__()
adv_loader = DataLoader(adv_set, batch_size=batch_size, shuffle=False)

print(f'number of images = {adv_set.__len__()}')
# Out:
# number of images = 200

# %% [markdown]
# ## Utils -- Benign Images Evaluation

# %%
# to evaluate the performance of model on benign images
def epoch_benign(model, loader, loss_fn):
    model.eval()
    train_acc, train_loss = 0.0, 0.0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        yp = model(x)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
    return train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# %% [markdown]
# ## Utils -- Attack Algorithm

# %%
# perform fgsm attack
def fgsm(model, x, y, loss_fn, epsilon=epsilon):
    x_adv = x.detach().clone() # initialize x_adv as original benign image x
    x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
    loss = loss_fn(model(x_adv), y) # calculate loss
    loss.backward() # calculate gradient
    # fgsm: use gradient ascent on x_adv to maximize loss
    x_adv = x_adv + epsilon * x_adv.grad.detach().sign()
    return x_adv

# TODO: perform iterative fgsm attack
# set alpha as the step size in Global Settings section
# alpha and num_iter can be decided by yourself
def ifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=20):
    # initialize x_adv as original benign image x
    x_adv = x.detach().clone()
    # write a loop of num_iter to represent the iterative times
    for i in range(num_iter):
    # for each loop
        x_adv = fgsm(model, x_adv, y, loss_fn, alpha)
        # call fgsm with (epsilon = alpha) to obtain new x_adv
        x_adv = torch.min(torch.max(x_adv, x-epsilon), x+epsilon)
        # clip new x_adv back to [x-epsilon, x+epsilon]
    return x_adv
    #pass

# %% [markdown]
# ## Utils -- Attack
#
# * Recall
#     * ToTensor() can be seen as a function where $T(x) = x/255$.
#     * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#
# * Inverse function
#     * Inverse Normalize() can be seen as a function where $N^{-1}(x) = x*std+mean$ where $mean$ and $std$ are constants.
#     * Inverse ToTensor() can be seen as a function where $T^{-1}(x) = x*255$.
#
# * Special Noted
#     * ToTensor() will also convert the image from shape (height, width, channel) to shape (channel, height, width), so we also need to transpose the shape back to original shape.
#     * Since our dataloader samples a batch of data, what we need here is to transpose **(batch_size, channel, height, width)** back to **(batch_size, height, width, channel)** using np.transpose.

# %%
# perform adversarial attack and generate adversarial examples
def gen_adv_examples(model, loader, attack, loss_fn):
    model.eval()
    adv_names = []
    train_acc, train_loss = 0.0, 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)
        x_adv = attack(model, x, y, loss_fn) # obtain adversarial examples
        yp = model(x_adv)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
        # store adversarial examples
        adv_ex = ((x_adv) * std + mean).clamp(0, 1) # to 0-1 scale
        adv_ex = (adv_ex * 255).clamp(0, 255) # 0-255 scale
        adv_ex = adv_ex.detach().cpu().data.numpy().round() # round to remove decimal part
        adv_ex = adv_ex.transpose((0, 2, 3, 1)) # transpose (bs, C, H, W) back to (bs, H, W, C)
        adv_examples = adv_ex if i == 0 else np.r_[adv_examples, adv_ex]
    return adv_examples, train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# create directory which stores adversarial examples
def create_dir(data_dir, adv_dir, adv_examples, adv_names):
    if os.path.exists(adv_dir) is not True:
        _ = shutil.copytree(data_dir, adv_dir)
    for example, name in zip(adv_examples, adv_names):
        im = Image.fromarray(example.astype(np.uint8)) # image pixel value should be unsigned int
        im.save(os.path.join(adv_dir, name))

# %% [markdown]
# ## Model / Loss Function
#
# Model list is available [here](https://github.com/osmr/imgclsmob/blob/master/pytorch/pytorchcv/model_provider.py). Please select models which has _cifar10 suffix. Some of the models cannot be accessed/loaded. You can safely skip them since TA's model will not use those kinds of models.

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model

model_list = ['resnet110_cifar10',
              'preresnet110_cifar10',
              'resnext272_2x32d_cifar10',
              'resnet1202_cifar10',
              'preresnet56_cifar10',
              'resnet1001_cifar10',
              'wrn20_10_32bit_cifar10',
              'ror3_164_cifar10',
              'rir_cifar10',
              'diapreresnet56_cifar10',
              'diapreresnet110_cifar10',
              'seresnet110_cifar10',
               ]


class Ensemble(nn.Module):
    def __init__(self, model_list, device='cuda'):
        super(Ensemble, self).__init__()
        self.model_list = model_list
        self.device = device

    def forward(self, x):
        outputs = []
        for i in range(0, len(self.model_list), 5):
            batch_models = self.model_list[i:i+5]
            batch_output = self.process_batch_models(batch_models, x)
            outputs.append(batch_output)

        avg_output = sum(outputs) / len(outputs)
        return avg_output

    def process_batch_models(self, batch_models, x):
        sum_output = 0
        for model_name in batch_models:
            model = ptcv_get_model(model_name, pretrained=True).to(self.device)
            model.eval()
            sum_output += model(x.clone())
            del model
        torch.cuda.empty_cache()
        return sum_output / len(batch_models)

model = Ensemble(model_list, device='cuda')
loss_fn = nn.CrossEntropyLoss()

benign_acc, benign_loss = epoch_benign(model, adv_loader, loss_fn)
print(f'benign_acc = {benign_acc:.5f}, benign_loss = {benign_loss:.5f}')
# Out:
# Downloading /root/.torch/models/resnext29_16x64d_cifar10-0241-4133d3d0.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.176/resnext29_16x64d_cifar10-0241-4133d3d0.pth.zip...
# Downloading /root/.torch/models/resnext29_32x4d_cifar10-0315-30413525.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.169/resnext29_32x4d_cifar10-0315-30413525.pth.zip...
# Downloading /root/.torch/models/preresnet56_cifar10-0449-e9124fcf.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.164/preresnet56_cifar10-0449-e9124fcf.pth.zip...
# Downloading /root/.torch/models/preresnet110_cifar10-0386-cc08946a.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.164/preresnet110_cifar10-0386-cc08946a.pth.zip...
# Downloading /root/.torch/models/preresnet164bn_cifar10-0364-429012d4.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.196/preresnet164bn_cifar10-0364-429012d4.pth.zip...
# Downloading /root/.torch/models/seresnet110_cifar10-0363-1ddec230.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.362/seresnet110_cifar10-0363-1ddec230.pth.zip...
# Downloading /root/.torch/models/sepreresnet56_cifar10-0451-fc23e153.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.379/sepreresnet56_cifar10-0451-fc23e153.pth.zip...
# Downloading /root/.torch/models/sepreresnet110_cifar10-0454-418daea9.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.379/sepreresnet110_cifar10-0454-418daea9.pth.zip...
# Downloading /root/.torch/models/diaresnet56_cifar10-0505-8ac86804.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.340/diaresnet56_cifar10-0505-8ac86804.pth.zip...
# Downloading /root/.torch/models/resnet1001_cifar10-0328-77a179e2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.201/resnet1001_cifar10-0328-77a179e2.pth.zip...
# Downloading /root/.torch/models/diapreresnet56_cifar10-0483-41cae958.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.343/diapreresnet56_cifar10-0483-41cae958.pth.zip...
# Downloading /root/.torch/models/resnet1202_cifar10-0353-1d5a2129.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.214/resnet1202_cifar10-0353-1d5a2129.pth.zip...
# Downloading /root/.torch/models/resnet56_cifar10-0452-628c42a2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.163/resnet56_cifar10-0452-628c42a2.pth.zip...
# Downloading /root/.torch/models/resnet110_cifar10-0369-4d6ca1fc.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.163/resnet110_cifar10-0369-4d6ca1fc.pth.zip...
# Downloading /root/.torch/models/diapreresnet110_cifar10-0425-56385016.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.343/diapreresnet110_cifar10-0425-56385016.pth.zip...
# benign_acc = 0.96000, benign_loss = 0.10345

# %% [markdown]
# ## FGSM

# %%
adv_examples, fgsm_acc, fgsm_loss = gen_adv_examples(model, adv_loader, fgsm, loss_fn)
print(f'fgsm_acc = {fgsm_acc:.5f}, fgsm_loss = {fgsm_loss:.5f}')

create_dir(root, 'fgsm', adv_examples, adv_names)
# Out:
# fgsm_acc = 0.66000, fgsm_loss = 1.50855

# %% [markdown]
# ## I-FGSM

# %%
# TODO: iterative fgsm attack
adv_examples, ifgsm_acc, ifgsm_loss = gen_adv_examples(model, adv_loader, ifgsm, loss_fn)
print(f'ifgsm_acc = {ifgsm_acc:.5f}, ifgsm_loss = {ifgsm_loss:.5f}')

create_dir(root, 'ifgsm', adv_examples, adv_names)
# Out:
# ifgsm_acc = 0.01500, ifgsm_loss = 12.95604

# %% [markdown]
# ## Compress the images

# %%
# %cd fgsm
# !tar zcvf ../fgsm.tgz *
# %cd ..

# %cd ifgsm
# !tar zcvf ../ifgsm.tgz *
# %cd ..
# Out:
# /content/ifgsm
# airplane/
# airplane/airplane3.png
# airplane/airplane19.png
# airplane/airplane2.png
# airplane/airplane1.png
# airplane/airplane10.png
# airplane/airplane5.png
# airplane/airplane18.png
# airplane/airplane11.png
# airplane/airplane14.png
# airplane/airplane17.png
# airplane/airplane8.png
# airplane/airplane16.png
# airplane/airplane7.png
# airplane/airplane12.png
# airplane/airplane13.png
# airplane/airplane20.png
# airplane/airplane4.png
# airplane/airplane6.png
# airplane/airplane15.png
# airplane/airplane9.png
# automobile/
# automobile/automobile19.png
# automobile/automobile4.png
# automobile/automobile12.png
# automobile/automobile7.png
# automobile/automobile18.png
# automobile/automobile20.png
# automobile/automobile2.png
# automobile/automobile3.png
# automobile/automobile15.png
# automobile/automobile10.png
# automobile/automobile8.png
# automobile/automobile5.png
# automobile/automobile11.png
# automobile/automobile6.png
# automobile/automobile16.png
# automobile/automobile13.png
# automobile/automobile17.png
# automobile/automobile14.png
# automobile/automobile9.png
# automobile/automobile1.png
# bird/
# bird/bird3.png
# bird/bird20.png
# bird/bird15.png
# bird/bird9.png
# bird/bird6.png
# bird/bird12.png
# bird/bird4.png
# bird/bird5.png
# bird/bird1.png
# bird/bird14.png
# bird/bird13.png
# bird/bird17.png
# bird/bird16.png
# bird/bird7.png
# bird/bird8.png
# bird/bird19.png
# bird/bird10.png
# bird/bird2.png
# bird/bird18.png
# bird/bird11.png
# cat/
# cat/cat16.png
# cat/cat12.png
# cat/cat6.png
# cat/cat3.png
# cat/cat7.png
# cat/cat11.png
# cat/cat5.png
# cat/cat14.png
# cat/cat8.png
# cat/cat19.png
# cat/cat13.png
# cat/cat9.png
# cat/cat15.png
# cat/cat4.png
# cat/cat20.png
# cat/cat18.png
# cat/cat17.png
# cat/cat2.png
# cat/cat1.png
# cat/cat10.png
# deer/
# deer/deer1.png
# deer/deer2.png
# deer/deer11.png
# deer/deer8.png
# deer/deer10.png
# deer/deer13.png
# deer/deer4.png
# deer/deer14.png
# deer/deer20.png
# deer/deer9.png
# deer/deer19.png
# deer/deer17.png
# deer/deer12.png
# deer/deer16.png
# deer/deer6.png
# deer/deer15.png
# deer/deer3.png
# deer/deer18.png
# deer/deer7.png
# deer/deer5.png
# dog/
# dog/dog18.png
# dog/dog2.png
# dog/dog17.png
# dog/dog6.png
# dog/dog10.png
# dog/dog1.png
# dog/dog16.png
# dog/dog14.png
# dog/dog8.png
# dog/dog13.png
# dog/dog9.png
# dog/dog4.png
# dog/dog12.png
# dog/dog3.png
# dog/dog7.png
# dog/dog5.png
# dog/dog11.png
# dog/dog20.png
# dog/dog19.png
# dog/dog15.png
# frog/
# frog/frog12.png
# frog/frog2.png
# frog/frog18.png
# frog/frog20.png
# frog/frog5.png
# frog/frog7.png
# frog/frog3.png
# frog/frog16.png
# frog/frog15.png
# frog/frog6.png
# frog/frog1.png
# frog/frog4.png
# frog/frog19.png
# frog/frog13.png
# frog/frog17.png
# frog/frog11.png
# frog/frog9.png
# frog/frog10.png
# frog/frog8.png
# frog/frog14.png
# horse/
# horse/horse7.png
# horse/horse17.png
# horse/horse13.png
# horse/horse3.png
# horse/horse19.png
# horse/horse5.png
# horse/horse20.png
# horse/horse6.png
# horse/horse1.png
# horse/horse9.png
# horse/horse14.png
# horse/horse18.png
# horse/horse2.png
# horse/horse4.png
# horse/horse15.png
# horse/horse16.png
# horse/horse12.png
# horse/horse11.png
# horse/horse10.png
# horse/horse8.png
# ship/
# ship/ship3.png
# ship/ship15.png
# ship/ship11.png
# ship/ship20.png
# ship/ship19.png
# ship/ship5.png
# ship/ship4.png
# ship/ship12.png
# ship/ship7.png
# ship/ship1.png
# ship/ship17.png
# ship/ship18.png
# ship/ship14.png
# ship/ship9.png
# ship/ship6.png
# ship/ship2.png
# ship/ship13.png
# ship/ship16.png
# ship/ship10.png
# ship/ship8.png
# truck/
# truck/truck8.png
# truck/truck12.png
# truck/truck18.png
# truck/truck20.png
# truck/truck2.png
# truck/truck7.png
# truck/truck11.png
# truck/truck3.png
# truck/truck17.png
# truck/truck19.png
# truck/truck14.png
# truck/truck15.png
# truck/truck16.png
# truck/truck9.png
# truck/truck6.png
# truck/truck10.png
# truck/truck4.png
# truck/truck1.png
# truck/truck13.png
# truck/truck5.png
# /content

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 20))
cnt = 0
for i, cls_name in enumerate(classes):
    path = f'{cls_name}/{cls_name}1.png'
    # benign image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'./data/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'benign: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
    # adversarial image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'./ifgsm/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'adversarial: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
plt.tight_layout()
plt.show()
